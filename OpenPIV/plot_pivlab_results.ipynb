# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
matfile = '../PIVlab results/6pixels/Karman_frame_00-10_intarea_6px_vorticity.mat'

# %%
import h5py
f = h5py.File(matfile, 'r')
# list(f.keys())

# %%
f['derived'].shape[0]
# Out:
# 11

# %%
x = np.array(f[f['resultslist'][0][0]])
y = np.array(f[f['resultslist'][0][1]])
 
fig, ax = plt.subplots(11,1,figsize=(12,50))

for i in range(f['derived'].shape[0]):
    tmp = np.array(f[f['derived'][i][0]])
    # for ax in axs:
    s = ax[i].pcolor(x,y,tmp, shading='nearest', vmin=-.3, vmax=.3)
    ax[i].invert_yaxis()
    ax[i].set_aspect(1)
    fig.colorbar(s, ax=ax[i])
